# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter
sns.set()

# %% [markdown]
# ## Bar Chart Homework Task I - Create a Horizontal Bar Chart

# %% [markdown]
# ### Your homework task is to use the data set from the section and create a Horizontal Bar Chart. In essence, the information on the chart will remain the same. But you’ll have swapped the x- and y-axis of the chart.
# ### This is your chance to explore the software, so you try out different options. For instance, choosing another color for the chart or exploring alternative chart formatting options.
# ### Tip: 	Python - in Matplotlib the barh() function creates a horizontal bar chart.

# %%
df_barchart = pd.read_csv("bar_chart_data.csv")
df_barchart
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
sns.set_style("whitegrid")
plt.barh(y = df_barchart["Brand"], 
         width = df_barchart["Cars Listings"], 
        color = "crimson")
plt.xlabel("Number of Listings", fontsize = 14)
plt.title("Cars Listings by Brand", fontsize = 16, fontweight = "bold")
sns.despine(top = "false", right = "false")
plt.show()

# %% [markdown]
# ## Bar Chart Homework Task II - Create Bar Chart of Ice Cream Shop Sales

# %% [markdown]
# ### You have a frequency distribution table with all the sales of an ice cream shop chain across four cities. Your task is to create a bar chart of the data.
#
# ### Step 1: Create the chart.
# ### Step 2: Make sure your chart has sufficient labeling and is well styled.
# ### Step 3: Interpret the chart.

# %%
df_icecream_shop = pd.read_csv("bar_chart_homework_data.csv")
df_icecream_shop
# Out:
#           Cities  Frequency
# 0       New York      12327
# 1             LA      17129
# 2  San Francisco      19923
# 3          Total      49379

# %%
plt.figure(figsize = (9, 6))
plt.bar(x = df_icecream_shop["Cities"], 
       height = df_icecream_shop["Frequency"], 
       color = "midnightblue")
plt.title("Frequency Distribution of All Sales", fontsize = 14, fontweight = "bold")
plt.ylabel("Frequency", fontsize = 13)
plt.xlabel("Cities", fontsize = 13)
plt.tight_layout()

# %% [markdown]
# Across the three cities, San Francisco has the highest frequency of distribution of ice cream sales followed by Los Angeles. Total frequency of all three cities were close to 50,000.

# %% [markdown]
# ## Area Chart Homework I

# %% [markdown]
# ### Create a stacked area chart using all four engine type categories on the chart. They are Gas, Petrol, Diesel, Other.
# ### Think about the order in which you’ll display the categories.
# ### Consider the colors, which would fit your graph.
# ### Finally, think about a setting in which you’d be required to present all four categories from the data. What would be the interpretation of your newly created chart?

# %%
df_engine_areachart = pd.read_csv("stacked_area_chart_data.csv")
df_engine_areachart
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# 23  2005   5785    7269   23551   1918
# 24  2006   6439   12372   18024   1878
# 25  2007  10902   21258   24683   1525
# 26  2008  12876   22090   25471   1516
# 27  2009   2179    5682   10191   1204
# 28  2010   2649    7222   13150    442
# 29  2011   3893   11628   23221   1688
# 30  2012   1899    8763   27958   1736
# 31  2013   1055    6517   16255    607
# 32  2014    409    1942    4703    329
# 33  2015     50     702    1172    125
# 34  2016      0     108     220     25

# %%
plt.figure(figsize = (12, 6))
sns.set_style("whitegrid")
colors = ["midnightblue", "cyan", "red", "black"]
labels = ["Diesel", "Petrol", "Gas", "Other"]
sns.set_style("white")
plt.stackplot(df_engine_areachart["Year"], 
             df_engine_areachart["Diesel"], 
             df_engine_areachart["Petrol"], 
             df_engine_areachart["Gas"], 
             df_engine_areachart["Other"], 
             colors = colors, 
             edgecolor = "none")
plt.xticks(df_engine_areachart["Year"], rotation = 45)
plt.ylabel("Number of Cars", fontsize = 13)
plt.title("Popularity of Engine Fuel Types (1982 - 2016)", fontsize = 14, weight = "bold")
sns.despine()
plt.legend(labels = labels, loc = "upper left")
plt.show()

# %% [markdown]
# The growth in number of cars had started to peak around 1999-2000 for all fuel types. Diesel was favored over other fuel types.
# Then towards 2008, the number of cars had dropped drastically with gas and petrol tanking the most. This was probably due to the
# financial mortgage crisis during that time period.

# %% [markdown]
# ## Area Chart Homework II - Create an Area Chart of a Company's Revenue

# %% [markdown]
# ### Your homework task is to create a stacked area chart of a printer company and its revenue for the last 12 months. The data set contains monthly values in the span of a year and features three revenue sources:
# ### -	International Printer Sales
# ### -	Domestic Printer Sales
# ### -	Services (fixed fee)
# ### Think about the ordering of the categories, as well as the appropriate colors when displaying your chart. After you’ve completed the chart think about interpretation. What does the chart show? Which would you say is the most important revenue source for the business and why? How does the performance of the company look when considering the Date factor?

# %%
df_revenue_12mos = pd.read_csv("area_chart_homework_data.csv")
df_revenue_12mos
# Out:
#           Date  International  Domestic  Services  Unnamed: 4  Unnamed: 5
# 0    1/28/2020           3200       300      2000         NaN         NaN
# 1    2/28/2020           4500       500      2000         NaN         NaN
# 2    3/28/2020           3000       600      2000         NaN         NaN
# 3    4/28/2020           2800       500      2000         NaN         NaN
# 4    5/28/2020           5300       400      2000         NaN         NaN
# 5    6/28/2020           3800       580      2000         NaN         NaN
# 6    7/28/2020           3500       490      2000         NaN         NaN
# 7    8/28/2020           2500       290      2000         NaN         NaN
# 8    9/28/2020           3400       500      2000         NaN         NaN
# 9   10/28/2020           5000       600      2000         NaN         NaN
# 10  11/28/2020           5500       500      2000         NaN         NaN
# 11  12/28/2020           4700       700      2000         NaN         NaN

# %%
df_revenue_12mos = df_revenue_12mos.drop(columns = ['Unnamed: 4', 'Unnamed: 5'])

international_rev = []
domestic_rev = []

for i in range(df_revenue_12mos.shape[0]):
    international_rev.append(df_revenue_12mos["International"][i] * 2000)
    domestic_rev.append(df_revenue_12mos["Domestic"][i] * 2000)
    
df_revenue_12mos['Domestic Revenue'] = domestic_rev
df_revenue_12mos['International Revenue'] = international_rev


df_revenue_12mos
# Out:
#           Date  International  Domestic  Services  Domestic Revenue  \
# 0    1/28/2020           3200       300      2000            600000
# 1    2/28/2020           4500       500      2000           1000000
# 2    3/28/2020           3000       600      2000           1200000
# 3    4/28/2020           2800       500      2000           1000000
# 4    5/28/2020           5300       400      2000            800000
# 5    6/28/2020           3800       580      2000           1160000
# 6    7/28/2020           3500       490      2000            980000
# 7    8/28/2020           2500       290      2000            580000
# 8    9/28/2020           3400       500      2000           1000000
# 9   10/28/2020           5000       600      2000           1200000
# 10  11/28/2020           5500       500      2000           1000000
# 11  12/28/2020           4700       700      2000           1400000
#
#     International Revenue
# 0                 6400000
# 1                 9000000
# 2                 6000000
# 3                 5600000
# 4                10600000
# 5                 7600000
# 6                 7000000
# 7                 5000000
# 8                 6800000
# 9                10000000
# 10               11000000
# 11                9400000

# %%
#It is important to have data go from largest (base) then smallest (top)
labels = ["International", "Services", "Domestic"]
colors = ["#165D86", "#33B5FF", "orange"]
sns.set_style("whitegrid")
plt.figure(figsize = (10, 8))
plt.margins(x=0)
plt.stackplot(df_revenue_12mos["Date"], 
              df_revenue_12mos["International"], 
              df_revenue_12mos["Services"], 
              df_revenue_12mos["Domestic"], 
             edgecolor = "none", 
             colors = colors)
plt.ylabel("Number of Sales", fontsize = 13)
plt.xticks(df_revenue_12mos["Date"], rotation = 45)
plt.legend(labels = labels, loc = "upper left")
plt.title("Monthly Revenue from Services & Printer Sales", fontsize = "14", weight = "bold")
sns.despine()
plt.show()

# %% [markdown]
# At a glance, services fee has not changed throughout the year, followed by minimal peaks in domestic and with international sales bringing in the most revenue to the company. Major peaks in February, May and November. As for drops in sales, we can see that demonstrated in April and August with the sales being the weakest.

# %% [markdown]
# ## Line Chart Homework - Create a Line Chart with New Index Data

# %% [markdown]
# ### Your Homework task is to create a line chart using the new index data which is from 2010 until 2020.
# ### After you’ve created your line chart:
# ### •	Think about narrowing down the time frame to a more specific period.
# ### •	Think about the interpretation of the chart with a specific time frame. Why have you chosen this period, specifically? What would you tell your audience or your colleagues if you were presenting this chart?

# %%
returns_10_20 = pd.read_csv("returns1020.csv")
returns_10_20
# Out:
#            Date   GSPCRet   FTSERet
# 0      1/1/2010  0.000000  0.000000
# 1      1/4/2010 -0.008912  0.000000
# 2      1/5/2010  0.014419  0.016147
# 3      1/6/2010  0.002693  0.004036
# 4      1/7/2010  0.000493  0.001358
# ...         ...       ...       ...
# 2626  1/27/2020 -0.025784  0.010429
# 2627  1/28/2020  0.002522 -0.022924
# 2628  1/29/2020  0.010478  0.009255
# 2629  1/30/2020 -0.010035  0.000388
# 2630  1/31/2020  0.007947 -0.013576
#
# [2631 rows x 3 columns]

# %%
returns_10_20["numeric_date"] = pd.to_datetime(returns_10_20["Date"])

# %%
returns_10_20["numeric_date"]
# Out:
# 0      2010-01-01
# 1      2010-01-04
# 2      2010-01-05
# 3      2010-01-06
# 4      2010-01-07
#           ...
# 2626   2020-01-27
# 2627   2020-01-28
# 2628   2020-01-29
# 2629   2020-01-30
# 2630   2020-01-31
# Name: numeric_date, Length: 2631, dtype: datetime64[ns]

# %%
labels = ["GSPC", "FTSE"]
plt.figure(figsize = (20, 8))
plt.plot(returns_10_20["numeric_date"], returns_10_20["GSPCRet"])
plt.plot(returns_10_20["numeric_date"], returns_10_20["FTSERet"])
plt.title("GSPC vs FTSE Returns (2010-2020)", fontsize = 14, fontweight = "bold")
plt.xlabel("Dates")
plt.ylabel("Returns")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
df_returns_Q3 = returns_10_20[(returns_10_20.numeric_date >= '2016-07-01') & 
                             (returns_10_20.numeric_date <= '2016-09-30')]

# %%
df_returns_Q3
# Out:
#            Date   GSPCRet   FTSERet numeric_date
# 1695   7/1/2016  0.012623  0.022673   2016-07-01
# 1696   7/4/2016  0.000000  0.011300   2016-07-04
# 1697   7/5/2016 -0.002044 -0.008437   2016-07-05
# 1698   7/6/2016 -0.005069  0.003542   2016-07-06
# 1699   7/7/2016  0.007671 -0.012497   2016-07-07
# ...         ...       ...       ...          ...
# 1756  9/26/2016 -0.006787 -0.000289   2016-09-26
# 1757  9/27/2016 -0.005791 -0.013228   2016-09-27
# 1758  9/28/2016  0.007367 -0.001511   2016-09-28
# 1759  9/29/2016  0.003261  0.006125   2016-09-29
# 1760  9/30/2016 -0.005713  0.010220   2016-09-30
#
# [66 rows x 4 columns]

# %%
plt.figure(figsize = (20, 8))
plt.plot(df_returns_Q3["numeric_date"], df_returns_Q3["GSPCRet"], color = "blue")
plt.plot(df_returns_Q3["numeric_date"], df_returns_Q3["FTSERet"], color = "crimson")
plt.title("GSPC vs TSE Returns 3rd Quarter 2016", fontsize = 14, fontweight = "bold")
plt.xlabel("Date")
plt.ylabel("Returns")
plt.legend (labels = labels, fontsize = "large")
plt.show()

# %% [markdown]
# We can see a sharp drop in returns of FTSE in July with it stabilizing between ewarly July to September.
# GSPC is mostly consistent all the way until early September where we see a sharp drop in returns but then it had corrected
# itself the new couple of days.

# %% [markdown]
# ## Histogram Homework Task - Create a Histogram Showing Distribution of Age

# %% [markdown]
# ### The data set for this assignment contains a survey of geodemographic features among 2000 participants. Your task is to create a histogram based on the Age variable in the data.
# ### •	Decide on how many bins or what intervals lengths are appropriate for the histogram
# ### •	What is the data distribution? What insight can you gain about the age/age groups of the participants in the survey?
# ### •	Don’t forget to format your chart by improving the colors and including proper chart labeling.

# %%
df_age_survey = pd.read_csv("histogram_survey_data.csv")
df_age_survey
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0
#
# [2000 rows x 8 columns]

# %%
sns.set_style("white")
plt.figure(figsize = (8, 6))
plt.hist(df_age_survey["Age"],
        bins = 12, 
        color = "#850D8F")
plt.title("Distribution of Age Among Participants", fontsize = 14, fontweight = "bold")
plt.xticks(np.arange(min(df_age_survey["Age"]), max(df_age_survey["Age"]), 5.0))
plt.xlabel("Age")
plt.ylabel("Number of Participants")
sns.despine()
plt.show()

# %% [markdown]
# There were quite a bit of participants between the age of 15-35 that had participated in the survey. Then there's a sharp decline after the age of 35 that had taken the survey.

# %% [markdown]
# ## Scatter Plot Homework Task - Create a Scatter Plot of Student Scores

# %% [markdown]
# ### Your task is to plot the GPA and SAT student scores using a scatter plot.
# ### •	Decide which will be your x- and y-axis
# ### •	Think about chart interpretation. What is the relationship between these variables?
# ### •	Consider altering the chart limits, so the y-axis doesn’t start from 0.

# %%
df_student_scores = pd.read_csv("student_scores_data.csv")
df_student_scores
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.figure(figsize = (12, 8))
plt.scatter(df_student_scores["SAT"], df_student_scores["GPA"], edgecolors= "black")
plt.xticks(np.arange(min(df_student_scores["SAT"]), max(df_student_scores["SAT"]), 100))
plt.xlabel("SAT Scores")
plt.title("Correlation between GPA and SAT Scores", fontsize = 14, fontweight = "bold")
plt.ylabel("GPA")
plt.ylim(2.25, 4.0)
plt.show()

# %% [markdown]
# There appears to be a correlation between the GPA and SAT scores. The higher your GPA is, the higher the SAT scores tends to be. There are some outliers but that doesn't affect the cluster from mid 3.0 GPA and 1800s SAT scores.

# %% [markdown]
# ## Regression Plot Homework Task - Regression Plot of Auto Insurance in Sweden

# %% [markdown]
# ### Create a regression plot on the data set of car insurance in Sweden.
# ### •	Decide which is your x- and which your y-axis
# ### •	What is the relationship between the two variables?
# ### •	How would you interpret the chart?
# ### •	What would be an appropriate chart title?

# %%
df_auto_insurance = pd.read_csv("regression_auto_insurance_sweden.csv")

# %%
df_auto_insurance
# Out:
#     Claims  Payment
# 0      108    392.5
# 1       19     46.2
# 2       13     15.7
# 3      124    422.2
# 4       40    119.4
# ..     ...      ...
# 58       9     87.4
# 59      31    209.8
# 60      14     95.5
# 61      53    244.6
# 62      26    187.5
#
# [63 rows x 2 columns]

# %%
sns.set(rc = {'figure.figsize': (9, 6)})
sns.regplot(x = "Claims", 
           y = "Payment", 
           data = df_auto_insurance,
           scatter_kws = {'color': 'k'}, 
           line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %%
sns.lmplot(x = "Claims", 
           y = "Payment", 
           data = df_auto_insurance, 
           height = 10, 
           scatter_kws = {'color': 'k'}, 
           line_kws = {'color': 'red'})
plt.xlabel("Claims")
plt.ylabel("Payment")
plt.title("Car Insurance Claims and Payment in Sweden", fontsize = 14, weight = "bold")
plt.show()

# %% [markdown]
# ## Bar and Line Chart Homework - Pareto Chart of Movie Goers' Complaints

# %% [markdown]
# ### Your goal for this homework task is to create a Pareto chart. A Pareto is a specific case of a bar and line chart. The specificity comes from the fact that the bars on the Pareto bar chart are displayed in decreasing order of frequency. The line chart on the other hand always shows the cumulative frequency on a Pareto. Cumulative frequency means the sum of frequencies occurring up to this point. So, for the first element, it will show the frequency of occurrence for the first element only. For the second element it will be the sum of frequency for the first and second element, and so on. The last cumulative frequency is 100% as it is the sum of all individual frequencies.
# ### Related to the Pareto chart is the Pareto principle, also known as the 80/20 rule. Observed for the first time by Italian economist Wilfredo Pareto, who realized that around 80% of the land in Italy was owned by about 20% of the people. As such, this phenomenon shows that usually around 80% of problems are caused by 20% of the people.
# ### Our data set for this task contains the top 5 Movie Goers complaints. Your task is to create a Pareto chart, based on the data.
# ### The complaints must be ordered in decreasing order of frequency. This will represent your bar chart.
# ### The cumulative frequency will be your line chart, represented as percentages. It must sum up to 100%, so your last value on the line chart must show 100%.

# %%
df_movie_complaints = pd.read_csv("bar_line_chart_homework.csv")

# %%
df_movie_complaints
# Out:
#   Movie Theater Goers Complaints  Number of complaints  frequency
# 0        Poor Projection Quality                  3821   0.727532
# 1                     Bad Volume                   684   0.857768
# 2                    Screen Size                   298   0.914509
# 3                      Bad Seats                   232   0.958682
# 4                         Queues                   217   1.000000

# %%
fig, ax = plt.subplots(figsize = (10, 7))

ax.bar(df_movie_complaints["Movie Theater Goers Complaints"], 
      df_movie_complaints["Number of complaints"], 
       color = 'k')
ax.set_ylabel("Number of Complaints",
              weight = "bold")
ax.tick_params(axis = "y", 
              width = 2,
              labelsize = "large")

ax1 = ax.twinx()
ax1.set_ylim(0, 1)

ax1.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))

ax1.plot(df_movie_complaints["Movie Theater Goers Complaints"], 
         df_movie_complaints["frequency"], 
         color = "#185846", 
         marker = "D")

ax1.set_ylabel("Frequency", 
              color = "#185846", 
              weight = "bold")

ax1.tick_params(axis = "y", 
               color = "#185846", 
               width = 2, 
               labelsize = "large")

ax.set_title("Frequency of Movie Goers Complaints on Certain Issues", fontsize = "14", weight = "bold")
# Out:
# Text(0.5, 1.0, 'Frequency of Movie Goers Complaints on Certain Issues')
